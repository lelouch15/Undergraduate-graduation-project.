# %%
from autogluon.tabular import TabularDataset,TabularPredictor
import pandas as pd

# %%
import pandas as pd
data=pd.read_csv(r".\data_try_2.csv").drop('Unnamed: 0',axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   111     175 non-null    int64
#  1   211     175 non-null    int64
#  2   X       175 non-null    float64
#  3   r       175 non-null    float64
#  4   E       175 non-null    float64
#  5   M       175 non-null    float64
#  6   rou     175 non-null    float64
#  7   Er      175 non-null    float64
#  8   Ea      175 non-null    float64
# dtypes: float64(7), int64(2)
# memory usage: 12.4 KB

# %%
from sklearn.model_selection import train_test_split
x_train,x_test=train_test_split(data,test_size=0.2)
data=TabularDataset(x_train)
data_1=TabularDataset(x_test)

# %%
predictor=TabularPredictor(label='Ea',eval_metric='r2').fit(train_data=data)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20230419_025943\"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels\ag-20230419_025943\"
# AutoGluon Version:  0.7.0
# Python Version:     3.8.0
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22621
# Train Data Rows:    140
# Train Data Columns: 8
# Label Column: Ea
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1.5, 0.01, 0.69121, 0.37733)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6222.53 MB
# 	Train Data (Original)  Memory Usage: 0.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 6 | ['X', 'r', 'E', 'M', 'rou', ...]
# 		('int', [])   : 2 | ['111', '211']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 6 | ['X', 'r', 'E', 'M', 'rou', ...]
# 		('int', ['bool']) : 2 | ['111', '211']
# 	0.0s = Fit runtime
# 	8 features in original data used to generate 8 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.05s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'r2'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 112, Val Rows: 28
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.43	 = Validation score   (r2)
# 	2.08s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.6579	 = Validation score   (r2)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.1869	 = Validation score   (r2)
# 	3.63s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.3789	 = Validation score   (r2)
# 	0.39s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	0.6827	 = Validation score   (r2)
# 	0.68s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.7946	 = Validation score   (r2)
# 	7.46s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	0.7928	 = Validation score   (r2)
# 	0.4s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	0.6552	 = Validation score   (r2)
# 	2.54s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.6072	 = Validation score   (r2)
# 	0.6s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.7006	 = Validation score   (r2)
# 	0.74s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.6836	 = Validation score   (r2)
# 	0.69s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.8376	 = Validation score   (r2)
# 	0.43s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 20.04s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20230419_025943\")

# %%
predictor.leaderboard(data_1,silent=True,extra_metrics=['mae'])
# Out:
#                   model  score_test  mean_absolute_error  score_val  \
# 0   WeightedEnsemble_L2    0.747633            -0.122057   0.837555
# 1         LightGBMLarge    0.725223            -0.122605   0.683571
# 2              CatBoost    0.718688            -0.116812   0.794576
# 3         ExtraTreesMSE    0.718643            -0.120022   0.792787
# 4       RandomForestMSE    0.676601            -0.123770   0.682688
# 5       NeuralNetFastAI    0.669251            -0.126207   0.655175
# 6              LightGBM    0.658050            -0.130734   0.378862
# 7        NeuralNetTorch    0.564591            -0.158822   0.700553
# 8               XGBoost    0.558920            -0.137488   0.607196
# 9        KNeighborsDist    0.487784            -0.151191   0.657943
# 10       KNeighborsUnif    0.462786            -0.150057   0.429952
# 11           LightGBMXT    0.246027            -0.200849   0.186873
#
#     pred_time_test  pred_time_val  fit_time  pred_time_test_marginal  \
# 0         0.016954       0.014961  8.639959                 0.002991
# 1         0.004987       0.002851  0.686196                 0.004987
# 2         0.003989       0.003989  7.463678                 0.003989
# 3         0.049868       0.029920  0.402491                 0.049868
# 4         0.041888       0.033276  0.681701                 0.041888
# 5         0.010970       0.012407  2.538767                 0.010970
# 6         0.001994       0.000997  0.386167                 0.001994
# 7         0.009974       0.009975  0.743351                 0.009974
# 8         0.012773       0.002993  0.602962                 0.012773
# 9         0.007979       0.008975  0.006981                 0.007979
# 10        0.009969       0.032402  2.081066                 0.009969
# 11        0.001994       0.000997  3.628995                 0.001994
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.000997           0.432929            2       True
# 1                 0.002851           0.686196            1       True
# 2                 0.003989           7.463678            1       True
# 3                 0.029920           0.402491            1       True
# 4                 0.033276           0.681701            1       True
# 5                 0.012407           2.538767            1       True
# 6                 0.000997           0.386167            1       True
# 7                 0.009975           0.743351            1       True
# 8                 0.002993           0.602962            1       True
# 9                 0.008975           0.006981            1       True
# 10                0.032402           2.081066            1       True
# 11                0.000997           3.628995            1       True
#
#     fit_order
# 0          12
# 1          11
# 2           6
# 3           7
# 4           5
# 5           8
# 6           4
# 7          10
# 8           9
# 9           2
# 10          1
# 11          3
